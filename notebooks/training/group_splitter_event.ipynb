# %% [markdown]
# # Group Splitter Event
#
# Train the event-level group splitter with the updated pipeline structure.

# %%
from pathlib import Path
from pioneerml.common.evaluation.plots.loss import LossCurvesPlot
from pioneerml.common.zenml import load_step_output
from pioneerml.common.zenml import utils as zenml_utils
from pioneerml.pipelines.training import group_splitting_event_pipeline
PROJECT_ROOT = zenml_utils.find_project_root()
zenml_utils.setup_zenml_for_notebook(root_path=PROJECT_ROOT, use_in_memory=True)
# Out:
# Using ZenML repository root: /workspace
# Ensure this is the top-level of your repo (.zen must live here).

# %%
# Build aligned parquet/probability inputs.
# Expected prediction shard naming: ml_output_XXX_preds.parquet
data_dir = Path(PROJECT_ROOT) / "data"
main_paths = sorted(data_dir.glob("ml_output_*.parquet"))
probs_dir = data_dir / "inference_outputs" / "group_classifier_event"
# Example: uncomment to select a smaller subset
# main_paths = main_paths[:1]
paired = []
missing_prob_paths = []
for main_path in main_paths:
    pred_path = probs_dir / main_path.name.replace(".parquet", "_preds.parquet")
    if pred_path.exists():
        paired.append((str(main_path), str(pred_path)))
    else:
        missing_prob_paths.append(str(pred_path))
if not paired:
    raise RuntimeError(
        "No aligned parquet/prediction pairs found. "
        "Run group-classifier-event inference first to generate *_preds.parquet files."
    )
if missing_prob_paths:
    print(f"Warning: missing {len(missing_prob_paths)} prediction shard(s); skipping those files.")
parquet_paths = [p for p, _ in paired]
group_probs_parquet_paths = [p for _, p in paired]
print(f"Using {len(parquet_paths)} shard(s) for group-splitter-event training.")
# Out:
# Warning: missing 7 prediction shard(s); skipping those files.
# Using 1 shard(s) for group-splitter-event training.

# %%
# Run the pipeline
pipeline_config = {
    "loader": {"config_json": {"time_window_ns": 1.0}},
    "hpo": {
        "enabled": True,
        "n_trials": 1,
        "max_epochs": 2,
        "batch_size": [1, 2],
        "storage": f"sqlite:///{PROJECT_ROOT}/.optuna/group_splitter_event_hpo.db",
    },
    "train": {"max_epochs": 2},
    "export": {
        "prefer_cuda": True,
        "export_dir": str(PROJECT_ROOT / "trained_models" / "groupsplitter_event"),
    },
}
run = group_splitting_event_pipeline.with_options(enable_cache=False)(
    parquet_paths=parquet_paths,
    group_probs_parquet_paths=group_probs_parquet_paths,
    pipeline_config=pipeline_config,
)
trained_module = load_step_output(run, "train_group_splitter_event")
hpo_params = load_step_output(run, "tune_group_splitter_event")
metrics = load_step_output(run, "evaluate_group_splitter_event")
export = load_step_output(run, "export_group_splitter_event")
print("hpo_params:", hpo_params)
if trained_module is not None:
    print("train_epoch_loss_history:", list(trained_module.train_epoch_loss_history))
    print("val_epoch_loss_history:", list(trained_module.val_epoch_loss_history))
    print("train_step_count:", len(trained_module.train_loss_history))
    print("val_step_count:", len(trained_module.val_loss_history))
print("metrics:", metrics)
print("export:", export)
# Out:
# Initiating a new run for the pipeline: group_splitting_event_pipeline.
# Caching is disabled by default for group_splitting_event_pipeline.
# Using user: default
# Using stack: default
#   deployer: default
#   artifact_store: default
#   orchestrator: default
# You can visualize your pipeline runs in the ZenML Dashboard. In order to try it locally, please run zenml login --local.
# Step load_group_splitter_event_dataset has started.
# Step load_group_splitter_event_dataset has finished in 0.504s.
# Step tune_group_splitter_event has started.
# [I 2026-02-07 22:37:30,107] Using an existing study with name 'group_splitter_event_hpo' instead of creating a new one.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# You are using a CUDA device ('NVIDIA GeForce RTX 5070') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type               ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model   │ GroupSplitterEvent │  535 K │ train │     0 │
# │ 1 │ loss_fn │ BCEWithLogitsLoss  │      0 │ train │     0 │
# └───┴─────────┴────────────────────┴────────┴───────┴───────┘
# Trainable params: 535 K
# Non-trainable params: 0
# Total params: 535 K
# Total estimated model params size (MB): 2
# Modules in train mode: 21
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# `Trainer.fit` stopped: `max_epochs=2` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [I 2026-02-07 22:38:06,393] Trial 3 finished with value: 0.10701956620058334 and parameters: {'lr': 0.0018921931122984998, 'weight_decay': 1.6074427369042372e-06, 'batch_size': 2, 'heads': 3, 'hidden': 210, 'layers': 1, 'dropout': 0.17630337833792395}. Best is trial 2 with value: 0.07049324048934147.
# Step tune_group_splitter_event has finished in 36.691s.
# Step train_group_splitter_event has started.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type               ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model   │ GroupSplitterEvent │  367 K │ train │     0 │
# │ 1 │ loss_fn │ BCEWithLogitsLoss  │      0 │ train │     0 │
# └───┴─────────┴────────────────────┴────────┴───────┴───────┘
# Trainable params: 367 K
# Non-trainable params: 0
# Total params: 367 K
# Total estimated model params size (MB): 1
# Modules in train mode: 53
# Modules in eval mode: 0
# Total FLOPs: 0
# Output()
# `Trainer.fit` stopped: `max_epochs=2` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [train_group_splitter_event] No materializer is registered for type <class 'pioneerml.common.training.lightning.GraphLightningModule'>, so the default Pickle materializer was used. Pickle is not production ready and should only be used for prototyping as the artifacts cannot be loaded when running with a different Python version. Please consider implementing a custom materializer for type <class 'pioneerml.common.training.lightning.GraphLightningModule'> according to the instructions at https://docs.zenml.io/concepts/artifacts/materializers
# Step train_group_splitter_event has finished in 1m59s.
# Step evaluate_group_splitter_event has started.
# Step evaluate_group_splitter_event has finished in 8.463s.
# Step export_group_splitter_event has started.
# Step export_group_splitter_event has finished in 0.831s.
# Pipeline run has finished in 2m48s.
# hpo_params: {'lr': 0.000597704776276469, 'weight_decay': 1.4847433939518869e-06, 'batch_size': 1, 'study_name': 'group_splitter_event_hpo', 'storage': 'sqlite:////workspace/.optuna/group_splitter_event_hpo.db', 'model': {'in_channels': 4, 'prob_dimension': 3, 'hidden': 100, 'heads': 2, 'layers': 3, 'dropout': 0.05023820679431069}} {'lr': 0.000597704776276469, 'weight_decay': 1.4847433939518869e-06, 'batch_size': 1, 'study_name': 'group_splitter_event_hpo', 'storage': 'sqlite:////workspace/.optuna/group_splitter_event_hpo.db', 'model': {'in_channels': 4, 'prob_dimension': 3, 'hidden': 100, 'heads': 2, 'layers': 3, 'dropout': 0.05023820679431069}}
# train_epoch_loss_history: [0.14959370772052202, 0.08840734815207105] [0.14959370772052202, 0.08840734815207105]
# val_epoch_loss_history: [0.9097951352596283, 0.08826168255176466, 0.07152103993361458] [0.9097951352596283, 0.08826168255176466, 0.07152103993361458]
# train_step_count: 1982 1982
# val_step_count: 1984 1984
# metrics: {'loss': 0.07050719052709681, 'accuracy': 0.9772566556930542, 'exact_match': 0.9645774364471436, 'confusion': [{'tp': 0.9172773163979808, 'fp': 0.04315258101286436, 'fn': 0.03957010258915486}, {'tp': 0.0, 'fp': 0.0, 'fn': 0.0}, {'tp': 0.9453419567909729, 'fp': 0.027686803357644146, 'fn': 0.026971239851382965}], 'threshold': 0.5, 'train_loss_history': [0.14959370772052202, 0.08840734815207105], 'train_loss_history_total_points': 2, 'val_loss_history': [0.9097951352596283, 0.08826168255176466, 0.07152103993361458], 'val_loss_history_total_points': 3, 'loss_plot_path': None} {'loss': 0.07050719052709681, 'accuracy': 0.9772566556930542, 'exact_match': 0.9645774364471436, 'confusion': [{'tp': 0.9172773163979808, 'fp': 0.04315258101286436, 'fn': 0.03957010258915486}, {'tp': 0.0, 'fp': 0.0, 'fn': 0.0}, {'tp': 0.9453419567909729, 'fp': 0.027686803357644146, 'fn': 0.026971239851382965}], 'threshold': 0.5, 'train_loss_history': [0.14959370772052202, 0.08840734815207105], 'train_loss_history_total_points': 2, 'val_loss_history': [0.9097951352596283, 0.08826168255176466, 0.07152103993361458], 'val_loss_history_total_points': 3, 'loss_plot_path': None}
# export: {'torchscript_path': '/workspace/trained_models/groupsplitter_event/groupsplitter_event_20260207_224016_torchscript.pt', 'metadata_path': '/workspace/trained_models/groupsplitter_event/groupsplitter_event_20260207_224016_meta.json'} {'torchscript_path': '/workspace/trained_models/groupsplitter_event/groupsplitter_event_20260207_224016_torchscript.pt', 'metadata_path': '/workspace/trained_models/groupsplitter_event/groupsplitter_event_20260207_224016_meta.json'}

# %%
# Plot loss curves
if trained_module is None:
    raise RuntimeError("No trained module loaded from pipeline run.")
LossCurvesPlot().render(trained_module, show=True)

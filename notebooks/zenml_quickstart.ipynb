# %% [markdown]
# # ZenML Quickstart for PIONEER ML
#
# Run the ZenML training pipeline to train a synthetic GroupClassifier.

# %%
from zenml.client import Client
from zenml_pipelines.training_pipeline import zenml_training_pipeline

# Initialize a local ZenML repo (creates .zenml/ if missing)
Client().initialize()

# Run the pipeline
run = zenml_training_pipeline()
run
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:5                                                                                    │
# │                                                                                                  │
# │    2 from zenml.integrations.pytorch_lightning.materializers import PyTorchLightningMateriali    │
# │    3 from zenml.client import Client                                                             │
# │    4                                                                                             │
# │ ❱  5 from zenml_pipelines.training_pipeline import zenml_training_pipeline                       │
# │    6                                                                                             │
# │    7 # Initialize a local ZenML repo (no server needed for quickstart)                           │
# ...

# %% [markdown]
# Inspect the run in the ZenML dashboard:
#
# ```bash
# zenml up
# ```
